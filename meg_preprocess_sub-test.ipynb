# %% [markdown]
# ## meg preprocess

# %% [markdown]
# ### overview

# %% [markdown]
# #### setup
# 1. mne install
# ```
# conda install --channel=conda-forge --name=base mamba
# mamba create --override-channels --channel=conda-forge --name=mne mne
# ```
#
# 2. freesurfer
# - https://surfer.nmr.mgh.harvard.edu/
#
# 3. afni
# - ttps://afni.nimh.nih.gov/pub/dist/doc/htmldoc/background_install/install_instructs/steps_linux_ubuntu20.html#quick-setup
#
# #### preprocess steps
# ##### mne
# 1. cut data
# 2. denoise
# 3. BEM model
# 4. source localization
# ##### region-based mask
# 1. downsample with 3dfractionize
# 2. mask with hcp atlas
#
# #### function
# 1. data: T1 and raw '.fif'., best with suffix '_raw_tsss_mc.fif'
# 2. ouput: '.mat' with 180 regions according to hcp glasser atlas.
# - https://afni.nimh.nih.gov/pub/dist/atlases/MNI_HCP/MNI_Glasser_HCP_2021_v1.0a/

# %% [markdown]
# ### setup

# %% [markdown]
# #### import necessary packages

# %%
# suppress warnings
import warnings
import sys 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import numpy as np #numpy's "nickname" is np
import os
from time import time
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from copy import deepcopy
import scipy
import csv
import shutil
import joblib
import datetime

import mne
import nibabel as nib
import scipy

# for mask
from nilearn.input_data import NiftiMasker,  MultiNiftiMasker
import nilearn as nil
from scipy import stats

# set log level
# mne.set_log_level("WARNING")
mne.set_log_level("INFO")

# display the plots inline 
# %matplotlib inline 
# autosave for every 5 secs
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# #### set environments

# %%
project_dir=os.getcwd()
data_dir=os.path.join(project_dir,"data")
freesurfer_dir=os.path.join(project_dir,"freesurfer")
preprocessed_dir=os.path.join(project_dir,"preprocessed")

if not os.path.isdir(preprocessed_dir):
    os.mkdir(preprocessed_dir)

subject_name="sub-test"
run_name="run01"

preprocessed_subject_path_str = os.path.join(preprocessed_dir, subject_name)

# %% [markdown]
# #### visualize raw data
# https://www.nmr.mgh.harvard.edu/mne/0.14/auto_tutorials/plot_visualize_raw.html

# %%
raw_meg_data_file_name = "run01_raw_tsss.fif"
raw_meg_data_file_path_str = os.path.join(data_dir, subject_name, run_name)
raw = mne.io.read_raw_fif(os.path.join(raw_meg_data_file_path_str, raw_meg_data_file_name), preload=True, allow_maxshield=True)

# %%
raw.plot(block=True)

# manually find start and end square wave singal
start_time = 18.14 # second
end_time = 621.69

# %%
data_length = 10 * 60 # second

raw_meg_data_file_name = "run01_raw_tsss.fif"
raw_meg_data_file_path_str = os.path.join(data_dir, subject_name, run_name)

raw = mne.io.read_raw_fif(os.path.join(raw_meg_data_file_path_str, raw_meg_data_file_name), preload=True, allow_maxshield=True)
raw = raw.crop(tmin=start_time, tmax=start_time + data_length)

cut_meg_data_file_name = "data_run01_raw_tsss.fif"
raw.save(os.path.join(raw_meg_data_file_path_str, cut_meg_data_file_name), overwrite=True)

# %% [markdown]
# #### cut to small data (for testing)

# %%
data_length = 10 # second
start_time = 18.14 # second

raw_meg_data_file_name = "run01_raw_tsss.fif"
raw_meg_data_file_path_str = os.path.join(data_dir, subject_name, run_name)

raw = mne.io.read_raw_fif(os.path.join(raw_meg_data_file_path_str, raw_meg_data_file_name), preload=True, allow_maxshield=True)
raw = raw.crop(tmin=start_time, tmax=start_time + data_length)

cut_meg_data_file_name = "cut10s_run01_raw_tsss.fif"
raw.save(os.path.join(raw_meg_data_file_path_str, cut_meg_data_file_name), overwrite=True)

# %% [markdown]
# ### denoise

# %%
raw_meg_data_file_name = "cut10s_run01_raw_tsss.fif"
cut_meg_data_file_path_str = os.path.join(data_dir, subject_name, run_name)
raw_filtered = mne.io.read_raw_fif(os.path.join(cut_meg_data_file_path_str, raw_meg_data_file_name), preload=True, allow_maxshield=True)


if not os.path.isdir(os.path.join(preprocessed_subject_path_str,"ICA_denoise")):
    os.mkdir(os.path.join(preprocessed_subject_path_str,"ICA_denoise"))
if not os.path.isdir(os.path.join(preprocessed_subject_path_str,"sensor_prep")):
    os.mkdir(os.path.join(preprocessed_subject_path_str,"sensor_prep"))

# find EOG epochs
try:
    eog_evoked = mne.preprocessing.create_eog_epochs(raw_filtered).average()
    eog_evoked.apply_baseline(baseline=(None, -0.2))
    # eogplot = eog_evoked.plot_joint(show=False)
    # for i in range(len(eogplot)):
    #     eogplot[i].savefig(preprocessed_subject_path_str + "/ICA_denoise/eog" + str(i + 1) + ".tiff")
except:
    print("RuntimeError: No EOG channel(s) found.")

# find ECG epochs
try:
    ecg_evoked = mne.preprocessing.create_ecg_epochs(raw_filtered).average()
    ecg_evoked.apply_baseline(baseline=(None, -0.2))
    # ecgplot = ecg_evoked.plot_joint(show=False)
    # for i in range(len(ecgplot)):
    #     ecgplot[i].savefig(preprocessed_subject_path_str + "/ICA_denoise/ecg" + str(i + 1) + ".tif")
except:
    print("RuntimeError: No ECG channel(s) found.")

# ICA
ica = mne.preprocessing.ICA(n_components=50, method="picard", random_state=0)
ica.fit(raw_filtered)
icaplot = ica.plot_components(title="ICA components", show=False)
for i in range(len(icaplot)):
    icaplot[i].savefig(preprocessed_subject_path_str + "/ICA_denoise/ICAfig" + str(i + 1) + ".tif")

# eog_indices, eog_scores = ica.find_bads_eog(raw_filtered)
ecg_indices, ecg_scores = ica.find_bads_ecg(raw_filtered)

ica.exclude = []
# ica.exclude = eog_indices + ecg_indices
ica.exclude = ecg_indices
raw_filtered = ica.apply(raw_filtered)

# save file and records
raw_filtered.save(os.path.join(preprocessed_subject_path_str,"sensor_prep", "preprocessed.fif"), overwrite=True)
# with open(os.path.join(preprocessed_subject_path_str,"03_flag.txt"), "w") as f:
#     f.write("Artefacts cleaned.")

# %% [markdown]
# ### bem model

# %%
preprocessed_subject_path_str = os.path.join(preprocessed_dir, subject_name)

subject_freesurfer_dir=os.path.join(freesurfer_dir, subject_name)

if not os.path.isdir(preprocessed_subject_path_str + "/fig"):
    os.mkdir(preprocessed_subject_path_str + "/fig")
if not os.path.isdir(preprocessed_subject_path_str + "/src"):
    os.mkdir(preprocessed_subject_path_str + "/src")

Brain = mne.viz.get_brain_class()
brain = Brain(
    subject="",
    views="lat",
    background="w",
    hemi="lh",
    surf="pial",
    subjects_dir=subject_freesurfer_dir,
    title="Surface Reconstruction",
    size=(1000, 800),
)
brain.add_annotation("aparc.a2009s", borders=False)
brain.save_image(preprocessed_subject_path_str + "/fig/recon.png")
brain.close()
# construct the BEM

info = mne.io.read_info(preprocessed_subject_path_str + "/sensor_prep/preprocessed.fif")
conductivity = (0.3,)

model = mne.make_bem_model(
    "", ico=5, conductivity=conductivity, subjects_dir=subject_freesurfer_dir
)
bem_sol = mne.make_bem_solution(model)
bem_model_fig = mne.viz.plot_bem(
    subject="", subjects_dir=subject_freesurfer_dir, orientation="coronal", show=False
)
bem_model_fig.savefig(preprocessed_subject_path_str + "/fig/bem_model_fig.tif")
mne.write_bem_solution(preprocessed_subject_path_str + "/src/bem_sol.h5", bem_sol, overwrite=True)

# automatic coregistreation
fiducials = "estimated"  # get fiducials from fsaverage
coreg = mne.coreg.Coregistration(
    info, subject="", subjects_dir=subject_freesurfer_dir, fiducials=fiducials
)
plot_kwargs = dict(
    subject="",
    subjects_dir=subject_freesurfer_dir,
    surfaces="head-dense",
    dig=True,
    eeg=[],
    meg="sensors",
    show_axes=True,
    coord_frame="meg",
)
coreg.fit_fiducials(verbose=True)
coreg.fit_icp(n_iterations=6, nasion_weight=2.0, verbose=True)
coreg.omit_head_shape_points(distance=5.0 / 1000)
coreg.fit_icp(n_iterations=20, nasion_weight=10.0, verbose=True)
dists = coreg.compute_dig_mri_distances() * 1e3  # in mm
print(
    f"Distance between HSP and MRI (mean/min/max):\n{np.mean(dists):.2f} mm "
    f"/ {np.min(dists):.2f} mm / {np.max(dists):.2f} mm"
)
mne.write_trans(preprocessed_subject_path_str + "/src/auto-trans.fif", coreg.trans, overwrite=True)
vol_src = mne.setup_volume_source_space(
    "",
    subjects_dir=subject_freesurfer_dir,
    surface=subject_freesurfer_dir + "/bem/inner_skull.surf",
    pos=4.0,
    mindist=1.0,
)
mne.write_source_spaces(preprocessed_subject_path_str + "/src/vol-src.fif", vol_src, overwrite=True)
surf_src = mne.setup_source_space(
    "", subjects_dir=subject_freesurfer_dir, spacing="oct6", add_dist="patch"
)
mne.write_source_spaces(preprocessed_subject_path_str + "/src/surf-src.fif", surf_src, overwrite=True)
# plot sources
plot_bem_kwargs = dict(
    subject="",
    subjects_dir=subject_freesurfer_dir,
    brain_surfaces="white",
    orientation="coronal",
    slices=[50, 100, 150, 200],
)
src_fig = mne.viz.plot_bem(src=vol_src, **plot_bem_kwargs, show=False)
src_fig.savefig(preprocessed_subject_path_str + "/fig/vol_src.tif")
src_fig = mne.viz.plot_bem(src=surf_src, **plot_bem_kwargs, show=False)
src_fig.savefig(preprocessed_subject_path_str + "/fig/surf_src.tif")

# save records
# with open(preprocessed_subject_path_str + "/BEM_log.txt", "w") as f:
#     f.write("BEM constructed.")

# %% [markdown]
# ### source localization

# %%
if not os.path.isdir(preprocessed_subject_path_str + "/fwd_model"):
    os.mkdir(preprocessed_subject_path_str + "/fwd_model")
if not os.path.isdir(preprocessed_subject_path_str + "/src"):
    os.mkdir(preprocessed_subject_path_str + "/src")

# load MEG data and compute the evoked data
vol_src = mne.read_source_spaces(preprocessed_subject_path_str + "/src/vol-src.fif")
surf_src = mne.read_source_spaces(preprocessed_subject_path_str + "/src/surf-src.fif")
trans = mne.read_trans(preprocessed_subject_path_str + "/src/auto-trans.fif")
bem_sol = mne.read_bem_solution(preprocessed_subject_path_str + "/src/bem_sol.h5")
data = mne.io.read_raw_fif(preprocessed_subject_path_str + "/sensor_prep/preprocessed.fif")

# mne.set_eeg_reference(data, projection=True)
cov = mne.compute_raw_covariance(
    data, method=["shrunk", "empirical"], rank="info"
)
fwd_vol = mne.make_forward_solution(
    preprocessed_subject_path_str + "/sensor_prep/preprocessed.fif",
    trans=trans,
    src=vol_src,
    bem=bem_sol,
    meg=True,
    eeg=False,
    n_jobs=20,
)

fwd_surf = mne.make_forward_solution(
    preprocessed_subject_path_str + "/sensor_prep/preprocessed.fif",
    trans=trans,
    src=surf_src,
    bem=bem_sol,
    meg=True,
    eeg=False,
    mindist=3.0,
    n_jobs=20,
)


inv_vol = mne.minimum_norm.make_inverse_operator(
    data.info, fwd_vol, cov, loose="auto", depth=0.8
)
inv_surf = mne.minimum_norm.make_inverse_operator(
    data.info, fwd_surf, cov, loose=0.2, depth=0.8
)

snr = 3.0
method = "MNE"
lambda2 = 1.0 / snr**2

# surface localisation
# volume localisation
# NOTE: volume files were separated into several sub-files to avoid memory error
if not os.path.isdir(preprocessed_subject_path_str + "/src/surf_file"):
    os.mkdir(preprocessed_subject_path_str + "/src/surf_file")
if not os.path.isdir(preprocessed_subject_path_str + "/src/vol_niifile"):
    os.mkdir(preprocessed_subject_path_str + "/src/vol_niifile")
if not os.path.isdir(preprocessed_subject_path_str + "/src/vol_stcfile"):
    os.mkdir(preprocessed_subject_path_str + "/src/vol_stcfile")

# %%
freesurfer_subject_path_dir = os.path.join(freesurfer_dir, subject_name)
freesurfer_fsaverage_path_dir = os.path.join(freesurfer_dir, "fsaverage")

subdata = data.copy()
stc = mne.minimum_norm.apply_inverse_raw(
    subdata,
    inv_surf,
    lambda2,
    method,
)
if os.path.isdir(preprocessed_subject_path_str + "/morph-maps"):
    shutil.rmtree(preprocessed_subject_path_str + "/morph-maps")
morph = mne.compute_source_morph(
    stc,
    subject_from=freesurfer_subject_path_dir,
    subject_to=freesurfer_fsaverage_path_dir,
    src_to=surf_src,
    subjects_dir=preprocessed_subject_path_str,
)
stc_fsaverage = morph.apply(stc)

brain = stc_fsaverage.plot(
    subjects_dir=freesurfer_subject_path_dir,
    initial_time=0.1,
    clim=dict(kind="value", lims=[3, 6, 9]),
    surface="flat",
    hemi="both",
    size=(1000, 500),
    smoothing_steps=5,
    time_viewer=False,
    add_data_kwargs=dict(colorbar_kwargs=dict(label_font_size=10)),
)

# to help orient us, let's add a parcellation (red=auditory, green=motor,
# blue=visual)
brain.add_annotation("HCPMMP1_combined", borders=2)

# You can save a movie like the one on our documentation website with:
# brain.save_movie(time_dilation=20, tmin=0.05, tmax=0.16,
#                  interpolation='linear', framerate=10)

stc_fsaverage.save(
    preprocessed_subject_path_str
    + "/src/surf_file/surf-TS_src",
    ftype="stc",
    overwrite=True,
)  # save a mne-file
del stc  # release memory
del stc_fsaverage

stc = mne.minimum_norm.apply_inverse_raw(
    subdata,
    inv_vol,
    lambda2,
    method,
)  # volume-source TC
stc.save_as_volume(
    preprocessed_subject_path_str
    + "/src/vol_niifile/vol-TS_src"
    + ".nii.gz",
    vol_src,
    dest="mri",
    format="nifti1",
    overwrite=True,
)  # save a nii-file
stc.save(
    preprocessed_subject_path_str
    + "/src/vol_stcfile/vol-TS_src_",
    ftype="stc",
    overwrite=True,
)  # save a mne-file
del subdata
del stc

if os.path.isdir(preprocessed_subject_path_str + "/morph-maps"):
    shutil.rmtree(preprocessed_subject_path_str + "/morph-maps")

# %% [markdown]
# ### roi_parc

# %% [markdown]
# #### surf

# %%
source_estimate_lh_str = preprocessed_subject_path_str + "/src/surf_file/surf-TS_src-lh.stc"
source_estimate_rh_str = preprocessed_subject_path_str + "/src/surf_file/surf-TS_src-rh.stc"

mne.datasets.fetch_hcp_mmp_parcellation(subjects_dir=freesurfer_dir, accept=True)
if not os.path.isdir(preprocessed_subject_path_str + "/src/ROI_tc"):
    os.mkdir(preprocessed_subject_path_str + "/src/ROI_tc")

surf_src = mne.read_source_spaces(preprocessed_subject_path_str + "/src/surf-src.fif")

# left hemisphere
stc_fsaverage_lh = mne.read_source_estimate(source_estimate_lh_str)
stc_fsaverage_lh.subject = ""
mne.datasets.fetch_hcp_mmp_parcellation(subjects_dir=freesurfer_dir, accept=True)
hcp_mmp_lh = mne.read_labels_from_annot(
    subject="",
    parc="lh.HCPMMP1",
    hemi="lh",
    annot_fname=os.path.join(freesurfer_dir, "fsaverage") + "/label/lh.HCPMMP1.annot",
    subjects_dir=os.path.join(freesurfer_dir, "fsaverage"),
)
ts_lh = mne.extract_label_time_course(
    stcs=stc_fsaverage_lh, labels=hcp_mmp_lh[1:181], src=surf_src
)
scipy.io.savemat(
    preprocessed_subject_path_str
    + "/src/ROI_tc/ts_HCPmmp_lh_"
    + subject_name
    + ".mat",
    {"ts_lh": ts_lh},
)
with open(
    preprocessed_subject_path_str
    + "/src/ROI_tc/lh_ROI_label_"
    + subject_name
    + ".csv",
    "w",
    newline="",
) as csvfile:
    ROIwriter = csv.writer(
        csvfile, delimiter=" ", quotechar="|", quoting=csv.QUOTE_MINIMAL
    )
    for i_ROI in range(1, 181):
        ROIwriter.writerow([hcp_mmp_lh[i_ROI]])

# right hemisphere
stc_fsaverage_rh = mne.read_source_estimate(source_estimate_rh_str)
stc_fsaverage_rh.subject = ""
hcp_mmp_rh = mne.read_labels_from_annot(
    subject="",
    parc="rh.HCPMMP1",
    hemi="rh",
    annot_fname=os.path.join(freesurfer_dir, "fsaverage") + "/label/rh.HCPMMP1.annot",
    subjects_dir=os.path.join(freesurfer_dir, "fsaverage"),
)
ts_rh = mne.extract_label_time_course(
    stcs=stc_fsaverage_rh, labels=hcp_mmp_rh[1:181], src=surf_src
)
scipy.io.savemat(
    preprocessed_subject_path_str
    + "/src/ROI_tc/ts_HCPmmp_rh_"
    + subject_name
    + ".mat",
    {"ts_rh": ts_rh},
)
with open(
    preprocessed_subject_path_str
    + "/src/ROI_tc/rh_ROI_label_"
    + subject_name
    + ".csv",
    "w",
    newline="",
) as csvfile:
    ROIwriter = csv.writer(
        csvfile, delimiter=" ", quotechar="|", quoting=csv.QUOTE_MINIMAL
    )
    for i_ROI in range(1, 181):
        ROIwriter.writerow([hcp_mmp_rh[i_ROI]])

# %% [markdown]
# #### vol

# %%
vol_src = mne.read_source_spaces(preprocessed_subject_path_str + "/src/vol-src.fif")
source_estimate_vol_str = preprocessed_subject_path_str + "/src/vol_stcfile/vol-TS_src_-vl.stc"
stc_vol= mne.read_source_estimate(source_estimate_vol_str)

print("check source vol...")
print("vol_src:", vol_src, '\n num:', 39 * 46 * 40)
print("stc_vol:", stc_vol)
# Out:
#     Reading a source space...
#     [done]
#     1 source spaces read
# check source vol...
# vol_src: <SourceSpaces: [<volume, shape=(39, 46, 40), n_used=30659>] MRI (surface RAS) coords, ~82.6 MB>
#  num: 71760
# stc_vol: <VolSourceEstimate | 30659 vertices, tmin : 0.0 (ms), tmax : 10000.0 (ms), tstep : 1.0 (ms), data shape : (30659, 10001), ~1.14 GB>

# %%
from scipy.io import loadmat

matdic = loadmat(preprocessed_subject_path_str + "/src/ROI_tc/" + "ts_HCPmmp_lh_sub-test.mat")

ts_lh = np.squeeze(matdic["ts_lh"])
print("ts_lh shape =", ts_lh.shape)
# Out:
# ts_lh shape = (180, 10001)

# %% [markdown]
# ### mask the nii data

# %% [markdown]
# #### load atlas brain regions

# %%
import os
# read design matrix
atlas_labels_txt = "Atlas MNI_Glasser_HCP_v1.0, 360 regions.txt"
atlas_labels_file = os.path.join(project_dir, "masks", atlas_labels_txt)

in_file = open(atlas_labels_file,'r')
brain_region_dict={}

# distinguish left and right brain regions
atlas_all_lines = in_file.readlines()

for i_line in range(0,len(atlas_all_lines)):
    if "u:L_" in atlas_all_lines[i_line]:
        
        atlas_brain_region_label = []

        # left brain regions
        atlas_line_left = atlas_all_lines[i_line]
        atlas_temp = atlas_line_left.split(":")
        atlas_brain_region_name = atlas_temp[1][2:]
        # print(atlas_brain_region_name)
        atlas_brain_region_label_left = int(atlas_temp[2][:-1])
        atlas_brain_region_label.append(atlas_brain_region_label_left)
        
        # right brain regions
        atlas_line_right = atlas_all_lines[i_line+1]
        atlas_temp = atlas_line_right.split(":")
        atlas_brain_region_name = atlas_temp[1][2:]
        atlas_brain_region_label_right = int(atlas_temp[2][:-1])
        atlas_brain_region_label.append(atlas_brain_region_label_right)

        # put into dict
        brain_region_dict[atlas_brain_region_name] = atlas_brain_region_label

print(len(brain_region_dict),brain_region_dict)
# Out:
# 180 {'Primary_Visual_Cortex': [1, 1001], 'Medial_Superior_Temporal_Area': [2, 1002], 'Sixth_Visual_Area': [3, 1003], 'Second_Visual_Area': [4, 1004], 'Third_Visual_Area': [5, 1005], 'Fourth_Visual_Area': [6, 1006], 'Eighth_Visual_Area': [7, 1007], 'Primary_Motor_Cortex': [8, 1008], 'Primary_Sensory_Cortex': [9, 1009], 'Frontal_Eye_Fields': [10, 1010], 'Premotor_Eye_Fields': [11, 1011], 'Area_55b': [12, 1012], 'Area_V3A': [13, 1013], 'RetroSplenial_Complex': [14, 1014], 'Parieto-Occipital_Sulcus_Area_2': [15, 1015], 'Seventh_Visual_Area': [16, 1016], 'IntraParietal_Sulcus_Area_1': [17, 1017], 'Fusiform_Face_Complex': [18, 1018], 'Area_V3B': [19, 1019], 'Area_Lateral_Occipital_1': [20, 1020], 'Area_Lateral_Occipital_2': [21, 1021], 'Posterior_InferoTemporal': [22, 1022], 'Middle_Temporal_Area': [23, 1023], 'Primary_Auditory_Cortex': [24, 1024], 'PeriSylvian_Language_Area': [25, 1025], 'Superior_Frontal_Language_Area': [26, 1026], 'PreCuneus_Visual_Area': [27, 1027], 'Superior_Temporal_Visual_Area': [28, 1028], 'Medial_Area_7P': [29, 1029], 'Area_7m': [30, 1030], 'Parieto-Occipital_Sulcus_Area_1': [31, 1031], 'Area_23d': [32, 1032], 'Area_ventral_23_a+b': [33, 1033], 'Area_dorsal_23_a+b': [34, 1034], 'Area_31p_ventral': [35, 1035], 'Area_5m': [36, 1036], 'Area_5m_ventral': [37, 1037], 'Area_23c': [38, 1038], 'Area_5L': [39, 1039], 'Dorsal_Area_24d': [40, 1040], 'Ventral_Area_24d': [41, 1041], 'Lateral_Area_7A': [42, 1042], 'Supplementary_And_Cingulate_Eye': [43, 1043], 'Area_6m_anterior': [44, 1044], 'Medial_Area_7A': [45, 1045], 'Lateral_Area_7P': [46, 1046], 'Area_7PC': [47, 1047], 'Area_Lateral_IntraParietal_ventral': [48, 1048], 'Ventral_IntraParietal_Complex': [49, 1049], 'Medial_IntraParietal_Area': [50, 1050], 'Area_1': [51, 1051], 'Area_2': [52, 1052], 'Area_3a': [53, 1053], 'Dorsal_area_6': [54, 1054], 'Area_6mp': [55, 1055], 'Ventral_Area_6': [56, 1056], 'Area_Posterior_24_prime': [57, 1057], 'Area_33_prime': [58, 1058], 'Anterior_24_prime': [59, 1059], 'Area_p32_prime': [60, 1060], 'Area_a24': [61, 1061], 'Area_dorsal_32': [62, 1062], 'Area_8BM': [63, 1063], 'Area_p32': [64, 1064], 'Area_10r': [65, 1065], 'Area_47m': [66, 1066], 'Area_8Av': [67, 1067], 'Area_8Ad': [68, 1068], 'Area_9_Middle': [69, 1069], 'Area_8B_Lateral': [70, 1070], 'Area_9_Posterior': [71, 1071], 'Area_10d': [72, 1072], 'Area_8C': [73, 1073], 'Area_44': [74, 1074], 'Area_45': [75, 1075], 'Area_47l_(47_lateral)': [76, 1076], 'Area_anterior_47r': [77, 1077], 'Rostral_Area_6': [78, 1078], 'Area_IFJa': [79, 1079], 'Area_IFJp': [80, 1080], 'Area_IFSp': [81, 1081], 'Area__IFSa': [82, 1082], 'Area_posterior_9-46v': [83, 1083], 'Area_46': [84, 1084], 'Area_anterior_9-46v': [85, 1085], 'Area_9-46d': [86, 1086], 'Area_9_anterior': [87, 1087], 'Area_10v': [88, 1088], 'Area_anterior_10p': [89, 1089], 'Polar_10p': [90, 1090], 'Area_11l': [91, 1091], 'Area_13l': [92, 1092], 'Orbital_Frontal_Complex': [93, 1093], 'Area_47s': [94, 1094], 'Area_Lateral_IntraParietal_dorsal': [95, 1095], 'Area_6_anterior': [96, 1096], 'Inferior_6-8_Transitional_Area': [97, 1097], 'Superior_6-8_Transitional_Area': [98, 1098], 'Area_43': [99, 1099], 'Area_OP4_PV': [100, 1100], 'Area_OP1_SII': [101, 1101], 'Area_OP2-3_VS': [102, 1102], 'Area_52': [103, 1103], 'RetroInsular_Cortex': [104, 1104], 'Area_PFcm': [105, 1105], 'Posterior_Insular_Area_2': [106, 1106], 'Area_TA2': [107, 1107], 'Frontal_Opercular_Area_4': [108, 1108], 'Middle_Insular_Area': [109, 1109], 'Piriform_Cortex': [110, 1110], 'Anterior_Ventral_Insular_Area': [111, 1111], 'Anterior_Agranular_Insula_Complex': [112, 1112], 'Frontal_Opercular_Area_1': [113, 1113], 'Frontal_Opercular_Area_3': [114, 1114], 'Frontal_Opercular_Area_2': [115, 1115], 'Area_PFt': [116, 1116], 'Anterior_IntraParietal_Area': [117, 1117], 'Entorhinal_Cortex': [118, 1118], 'PreSubiculum': [119, 1119], 'Hippocampus': [120, 1120], 'ProStriate_Area': [121, 1121], 'Perirhinal_Ectorhinal_Cortex': [122, 1122], 'Area_STGa': [123, 1123], 'ParaBelt_Complex': [1 ...

# %%
brain_region_name_list = list(brain_region_dict.keys())
brain_region_label_list = list(brain_region_dict.values())

# %% [markdown]
# #### load hcp mni atlas

# %%
# Load the mask image
mni_glasser_hcp_atlas_name = "MNI_Glasser_HCP_v1.0.nii.gz"
mni_glasser_hcp_atlas_file = os.path.join(project_dir, "masks", mni_glasser_hcp_atlas_name)

mni_glasser_hcp_atlas_mask = nib.load(mni_glasser_hcp_atlas_file)
mni_glasser_hcp_atlas_mask_data = mni_glasser_hcp_atlas_mask.get_fdata()
print("mni_glasser_hcp_atlas_mask_data.shape:", mni_glasser_hcp_atlas_mask_data.shape)
# Out:
# mni_glasser_hcp_atlas_mask_data.shape: (193, 229, 193)

# %%
# load nii data
current_file_str = preprocessed_subject_path_str + "/src/vol_niifile/vol-TS_src.nii.gz"
nii_data = nib.load(current_file_str)
nii_data = nil.image.index_img(nii_data, slice(0, 1))

saved_mask_name = "vol_ts_src.nii.gz"
mask_path = os.path.join(project_dir, "masks", saved_mask_name)
nib.save(nii_data, mask_path)
print("nii_data.shape:", nii_data.shape)
# Out:
# nii_data.shape: (39, 46, 40, 1)

# %% [markdown]
# #### resample

# %%
# %%bash
# #!/bin/bash
# export PATH=$PATH:/home/brain/abin
#
# project_dir="/home/brain/Workspace/meg_driving/preprocess"
#
# 3dfractionize -template ${project_dir}/masks/vol_ts_src.nii.gz -input ${project_dir}/masks/MNI_Glasser_HCP_v1.0.nii.gz -clip 0.00001 -preserve -prefix ${project_dir}/masks/resampled_mni_mask.nii.gz -overwrite

# %%
# Load the mask image
resampled_mni_mask_name = "resampled_mni_mask.nii.gz"
resampled_mni_mask_file = os.path.join(project_dir, "masks", resampled_mni_mask_name)

resampled_mni_mask = nib.load(resampled_mni_mask_file)
resampled_mni_mask_data = resampled_mni_mask.get_fdata()
print("resampled_mni_mask_data.shape:", resampled_mni_mask_data.shape)
# Out:
# resampled_mni_mask_data.shape: (39, 46, 40)

# %% [markdown]
# #### create region-based masks

# %%
for i_brain_region_name in np.arange(0, len(brain_region_name_list)):
  
    brain_region_name = brain_region_name_list[i_brain_region_name]

    # mask_name = "resampled_MNI_Glasser_HCP_neural_mask.nii.gz"
    mask_name = "resampled_mni_mask.nii.gz"
    # mask_name = "MNI_Glasser_HCP_v1.0.nii.gz"
    
    mask_file = os.path.join(project_dir, "masks", mask_name)

    # Load the mask image
    mask = nib.load(mask_file)
    mask_data = mask.get_fdata()

    if i_brain_region_name != 0: # remove the effect of first region V1, id V1 is same as mask 0
      mask_data[mask_data==1] = 0

    for i_num_region in brain_region_label_list[i_brain_region_name]:
        mask_data[mask_data==i_num_region] = 1

    mask_data[mask_data!=1] = 0

    voxel_num = np.count_nonzero(mask_data[mask_data!=0])
    print(brain_region_name, voxel_num)

    mask_nifti = nib.Nifti1Image(mask_data, mask.affine, mask.header)

    saved_mask_name = brain_region_name+"_resampled_mni_mask.nii.gz"

    mask_path = os.path.join(project_dir, "masks" , "region_based_masks", saved_mask_name)

    nib.save(mask_nifti, mask_path)

# %% [markdown]
# #### mask the nii data

# %%
brain_region_nii_data_list = []

for brain_region_name in brain_region_name_list:

    print('brain_region_name:',brain_region_name)

    ### load mask
    mask_name = brain_region_name+"_resampled_mni_mask.nii.gz"
    mask_file = os.path.join(project_dir, "masks", "region_based_masks", mask_name)

    # Load the mask image
    mask = nib.load(mask_file)

    mask_data = mask.get_fdata()

    voxel_num = np.count_nonzero(mask_data[mask_data!=0])

    print(voxel_num)
    if voxel_num != 0: 

        sub_dir = os.path.join(preprocessed_dir, subject_name)

        # load nii data
        current_file_str = preprocessed_subject_path_str + "/src/vol_niifile/vol-TS_src.nii.gz"
        nii_data = nib.load(current_file_str)

        # mask bold signal
        nifti_masker = nil.input_data.NiftiMasker(mask_img=mask)
        masked_data = nifti_masker.fit_transform(nii_data)
        masked_data = masked_data.T

        # do it for epi data
        masked_data = stats.zscore(masked_data, axis=1, ddof=1)
        masked_data = np.nan_to_num(masked_data)
        # print("masked_data shape (voxel_num,TR_num)", masked_data.shape)

        # add a brain region
        brain_region_nii_data_list.append(masked_data)

    elif voxel_num == 0:

        masked_data = np.empty((0,0), float)

        brain_region_nii_data_list.append(masked_data)
# Out:
# brain_region_name: Primary_Visual_Cortex
# 272
# brain_region_name: Medial_Superior_Temporal_Area
# 41
# brain_region_name: Sixth_Visual_Area
# 44
# brain_region_name: Second_Visual_Area
# 201
# brain_region_name: Third_Visual_Area
# 114
# brain_region_name: Fourth_Visual_Area
# 47
# brain_region_name: Eighth_Visual_Area
# 47
# brain_region_name: Primary_Motor_Cortex
# 361
# brain_region_name: Primary_Sensory_Cortex
# 182
# brain_region_name: Frontal_Eye_Fields
# 87
# brain_region_name: Premotor_Eye_Fields
# 57
# brain_region_name: Area_55b
# 107
# brain_region_name: Area_V3A
# 0
# brain_region_name: RetroSplenial_Complex
# 191
# brain_region_name: Parieto-Occipital_Sulcus_Area_2
# 130
# brain_region_name: Seventh_Visual_Area
# 3
# brain_region_name: IntraParietal_Sulcus_Area_1
# 72
# brain_region_name: Fusiform_Face_Complex
# 200
# brain_region_name: Area_V3B
# 26
# brain_region_name: Area_Lateral_Occipital_1
# 12
# brain_region_name: Area_Lateral_Occipital_2
# 7
# brain_region_name: Posterior_InferoTemporal
# 9
# brain_region_name: Middle_Temporal_Area
# 40
# brain_region_name: Primary_Auditory_Cortex
# 34
# brain_region_name: PeriSylvian_Language_Area
# 120
# brain_region_name: Superior_Frontal_Language_Area
# 127
# brain_region_name: PreCuneus_Visual_Area
# 106
# brain_region_name: Superior_Temporal_Visual_Area
# 108
# brain_region_name: Medial_Area_7P
# 63
# brain_region_name: Area_7m
# 86
# brain_region_name: Parieto-Occipital_Sulcus_Area_1
# 120
# brain_region_name: Area_23d
# 48
# brain_region_name: Area_ventral_23_a+b
# 44
# brain_region_name: Area_dorsal_23_a+b
# 55
# brain_region_name: Area_31p_ventral
# 57
# brain_region_name: Area_5m
# 67
# brain_region_name: Area_5m_ventral
# 111
# brain_region_name: Area_23c
# 128
# brain_region_name: Area_5L
# 17
# brain_region_name: Dorsal_Area_24d
# 141
# brain_region_name: Ventral_Area_24d
# 65
# brain_region_name: Lateral_Area_7A
# 51
# brain_region_name: Supplementary_And_Cingulate_Eye
# 141
# brain_region_name: Area_6m_anterior
# 96
# brain_region_name: Medial_Area_7A
# 113
# brain_region_name: Lateral_Area_7P
# 70
# brain_region_name: Area_7PC
# 130
# brain_region_name: Area_Lateral_IntraParietal_ventral
# 101
# brain_region_name: Ventral_IntraParietal_Complex
# 52
# brain_region_name: Medial_IntraParietal_Area
# 124
# brain_region_name: Area_1
# 280
# brain_region_name: Area_2
# 216
# brain_region_name: Area_3a
# 146
# brain_region_name: Dorsal_area_6
# 93
# brain_region_name: Area_6mp
# 74
# brain_region_name: Ventral_Area_6
# 129
# brain_region_name: Area_Posterior_24_prime
# 60
# brain_region_name: Area_33_prime
# 91
# brain_region_name: Anterior_24_prime
# 52
# brain_region_name: Area_p32_prime
# 87
# brain_region_name: Area_a24
# 111
# brain_region_name: Area_dorsal_32
# 126
# brain_region_name: Area_8BM
# 163
# brain_region_name: Area_p32
# 83
# brain_region_name: Area_10r
# 57
# brain_region_name: Area_47m
# 37
# brain_region_name: Area_8Av
# 293
# brain_region_name: Area_8Ad
# 183
# brain_region_name: Area_9_Middle
# 302
# brain_region_name: Area_8B_Lateral
# 215
# brain_region_name: Area_9_Posterior
# 154
# brain_region_name: Area_10d
# 188
# brain_region_name: Area_8C
# 199
# brain_region_name: Area_44
# 116
# brain_region_name: Area_45
# 178
# brain_region_name: Area_47l_(47_lateral)
# 139
# brain_region_name: Area_anterior_47r
# 215
# brain_region_name: Rostral_Area_6
# 155
# brain_region_name: Area_IFJa
# 67
# brain_region_name: Area_IFJp
# 55
# brain_region_name: Area_IFSp
# 89
# brain_region_name: Area__IFSa
# 135
# brain_region_name: Area_posterior_9-46v
# 188
# brain_region_name: Area_46
# 247
# brain_region_name: Area_anterior_9-46v
# 153
# brain_region_name: Area_9-46d
# 249
# brain_region_name: Area_9_anterior
# 176
# brain_region_name: Area_10v
# 140
# brain_region_name: Area_anterior_10p
# 102
# brain_region_name: Polar_10p
# 127
# brain_region_name: Area_11l
# 199
# brain_region_name: Area_13l
# 109
# brain_region_name: Orbital_Frontal_Complex
# 249
# brain_region_name: Area_47s
# 140
# brain_region_name: Area_Lateral_IntraParietal_dorsal
# 63
# brain_region_name: Area_6_anterior
# 222
# brain_region_name: Inferior_6-8_Transitional_Area
# 115
# brain_region_name: Superior_6-8_Transitional_Area
# 91
# brain_region_name: Area_43
# 82
# brain_region_name: Area_OP4_PV
# 103
# brain_region_name: Area_OP1_SII
# 52
# brain_region_name: Area_OP2-3_VS
# 47
# brain_region_name: Area_52
# 49
# brain_region_name: RetroInsular_Cortex
# 88
# brain_region_name: Area_PFcm
# 67
# brain_region_name: Posterior_Insular_Area_2
# 117
# brain_region_name: Area_TA2
# 69
# brain_region_name: Frontal_Opercular_Area_4
# 100
# brain_region_name: Middle_Insular_Area
# 90
# brain_region_name: Piriform_Cortex
# 129
# brain_region_name: Anterior_Ventral_Insular_Area
# 84
# brain_region_name: Anterior_Agranular_Insula_Complex
# 81
# brain_region_name: Frontal_Opercular_Area_1
# 39
# brain_region_name: Frontal_Opercular_Area_3
# 46
# brain_region_name: Frontal_Opercular_Area_2
# 49
# brain_region_name: Area_PFt
# 102
# brain_region_name: Anterior_IntraParietal_Area
# 126
# brain_region_name: Entorhinal_Cortex
# 129
# brain_region_name: PreSubiculum
# 113
# brain_region_name: Hippocampus
# 273
# brain_region_name: ProStriate_Area
# 68
# brain_region_name: Perirhinal_Ectorhinal_Cortex
# 231
# brain_region_name: Area_STGa
# 122
# brain_region_name: ParaBelt_Complex
# 70
# brain_region_name: Auditory_5_Complex
# 172
# brain_region_name: ParaHippocampal_Area_1
# 52
# brain_region_name: ParaHippocampal_Area_3
# 71
# brain_region_name: Area_STSd_anterior
# 84
# brain_region_name: Area_STSd_posterior
# 117
# brain_region_name: Area_STSv_posterior
# 121
# brain_region_name: Area_TG_dorsal
# 528
# brain_region_name: Area_TE1_anterior
# 249
# brain_region_name: Area_TE1_posterior
# 340
# brain_region_name: Area_TE2_anterior
# 301
# brain_region_name: Area_TF
# 230
# brain_region_name: Area_TE2_posterior
# 182
# brain_region_name: Area_PHT
# 185
# brain_region_name: Area_PH
# 160
# brain_region_name: Area_TemporoParietoOccipital_Junction_1
# 156
# brain_region_name: Area_TemporoParietoOccipital_Junction_2
# 96
# brain_region_name: Area_TemporoParietoOccipital_Junction_3
# 65
# brain_region_name: Dorsal_Transitional_Visual_Area
# 76
# brain_region_name: Area_PGp
# 56
# brain_region_name: Area_IntraParietal_2
# 94
# brain_region_name: Area_IntraParietal_1
# 74
# brain_region_name: Area_IntraParietal_0
# 51
# brain_region_name: Area_PF_opercular
# 75
# brain_region_name: Area_PF_Complex
# 279
# brain_region_name: Area_PFm_Complex
# 427
# brain_region_name: Area_PGi
# 236
# brain_region_name: Area_PGs
# 148
# brain_region_name: Area_V6A
# 0
# brain_region_name: VentroMedial_Visual_Area_1
# 45
# brain_region_name: VentroMedial_Visual_Area_3
# 44
# brain_region_name: ParaHippocampal_Area_2
# 40
# brain_region_name: Area_V4t
# 36
# brain_region_name: Area_FST
# 79
# brain_region_name: Area_V3CD
# 2
# brain_region_name: Area_Lateral_Occipital_3
# 33
# brain_region_name: VentroMedial_Visual_Area_2
# 45
# brain_region_name: Area_31pd
# 61
# brain_region_name: Area_31a
# 47
# brain_region_name: Ventral_Visual_Complex
# 159
# brain_region_name: Area_25
# 112
# brain_region_name: Area_s32
# 41
# brain_region_name: posterior_OFC_Complex
# 160
# brain_region_name: Area_Posterior_Insular_1
# 90
# brain_region_name: Insular_Granular_Complex
# 55
# brain_region_name: Area_Frontal_Opercular
# 77
# brain_region_name: Area_posterior_10p
# 119
# brain_region_name: Area_posterior_47r
# 101
# brain_region_name: Area_TG_Ventral
# 219
# brain_region_name: Medial_Belt_Complex
# 59
# brain_region_name: Lateral_Belt_Complex
# 48
# brain_region_name: Auditory_4_Complex
# 184
# brain_region_name: Area_STSv_anterior
# 85
# brain_region_name: Area_TE1_Middle
# 171
# brain_region_name: Para-Insular_Area
# 52
# brain_region_name: Area_anterior_32_prime
# 84
# brain_region_name: Area_posterior_24
# 113

# %%
print("num of brain regions:", len(brain_region_nii_data_list))

for i in range(0, len(brain_region_name_list)):
    print(brain_region_name_list[i],':',brain_region_nii_data_list[i].shape)
# Out:
# num of brain regions: 180
# Primary_Visual_Cortex : (272, 10001)
# Medial_Superior_Temporal_Area : (41, 10001)
# Sixth_Visual_Area : (44, 10001)
# Second_Visual_Area : (201, 10001)
# Third_Visual_Area : (114, 10001)
# Fourth_Visual_Area : (47, 10001)
# Eighth_Visual_Area : (47, 10001)
# Primary_Motor_Cortex : (361, 10001)
# Primary_Sensory_Cortex : (182, 10001)
# Frontal_Eye_Fields : (87, 10001)
# Premotor_Eye_Fields : (57, 10001)
# Area_55b : (107, 10001)
# Area_V3A : (0, 0)
# RetroSplenial_Complex : (191, 10001)
# Parieto-Occipital_Sulcus_Area_2 : (130, 10001)
# Seventh_Visual_Area : (3, 10001)
# IntraParietal_Sulcus_Area_1 : (72, 10001)
# Fusiform_Face_Complex : (200, 10001)
# Area_V3B : (26, 10001)
# Area_Lateral_Occipital_1 : (12, 10001)
# Area_Lateral_Occipital_2 : (7, 10001)
# Posterior_InferoTemporal : (9, 10001)
# Middle_Temporal_Area : (40, 10001)
# Primary_Auditory_Cortex : (34, 10001)
# PeriSylvian_Language_Area : (120, 10001)
# Superior_Frontal_Language_Area : (127, 10001)
# PreCuneus_Visual_Area : (106, 10001)
# Superior_Temporal_Visual_Area : (108, 10001)
# Medial_Area_7P : (63, 10001)
# Area_7m : (86, 10001)
# Parieto-Occipital_Sulcus_Area_1 : (120, 10001)
# Area_23d : (48, 10001)
# Area_ventral_23_a+b : (44, 10001)
# Area_dorsal_23_a+b : (55, 10001)
# Area_31p_ventral : (57, 10001)
# Area_5m : (67, 10001)
# Area_5m_ventral : (111, 10001)
# Area_23c : (128, 10001)
# Area_5L : (17, 10001)
# Dorsal_Area_24d : (141, 10001)
# Ventral_Area_24d : (65, 10001)
# Lateral_Area_7A : (51, 10001)
# Supplementary_And_Cingulate_Eye : (141, 10001)
# Area_6m_anterior : (96, 10001)
# Medial_Area_7A : (113, 10001)
# Lateral_Area_7P : (70, 10001)
# Area_7PC : (130, 10001)
# Area_Lateral_IntraParietal_ventral : (101, 10001)
# Ventral_IntraParietal_Complex : (52, 10001)
# Medial_IntraParietal_Area : (124, 10001)
# Area_1 : (280, 10001)
# Area_2 : (216, 10001)
# Area_3a : (146, 10001)
# Dorsal_area_6 : (93, 10001)
# Area_6mp : (74, 10001)
# Ventral_Area_6 : (129, 10001)
# Area_Posterior_24_prime : (60, 10001)
# Area_33_prime : (91, 10001)
# Anterior_24_prime : (52, 10001)
# Area_p32_prime : (87, 10001)
# Area_a24 : (111, 10001)
# Area_dorsal_32 : (126, 10001)
# Area_8BM : (163, 10001)
# Area_p32 : (83, 10001)
# Area_10r : (57, 10001)
# Area_47m : (37, 10001)
# Area_8Av : (293, 10001)
# Area_8Ad : (183, 10001)
# Area_9_Middle : (302, 10001)
# Area_8B_Lateral : (215, 10001)
# Area_9_Posterior : (154, 10001)
# Area_10d : (188, 10001)
# Area_8C : (199, 10001)
# Area_44 : (116, 10001)
# Area_45 : (178, 10001)
# Area_47l_(47_lateral) : (139, 10001)
# Area_anterior_47r : (215, 10001)
# Rostral_Area_6 : (155, 10001)
# Area_IFJa : (67, 10001)
# Area_IFJp : (55, 10001)
# Area_IFSp : (89, 10001)
# Area__IFSa : (135, 10001)
# Area_posterior_9-46v : (188, 10001)
# Area_46 : (247, 10001)
# Area_anterior_9-46v : (153, 10001)
# Area_9-46d : (249, 10001)
# Area_9_anterior : (176, 10001)
# Area_10v : (140, 10001)
# Area_anterior_10p : (102, 10001)
# Polar_10p : (127, 10001)
# Area_11l : (199, 10001)
# Area_13l : (109, 10001)
# Orbital_Frontal_Complex : (249, 10001)
# Area_47s : (140, 10001)
# Area_Lateral_IntraParietal_dorsal : (63, 10001)
# Area_6_anterior : (222, 10001)
# Inferior_6-8_Transitional_Area : (115, 10001)
# Superior_6-8_Transitional_Area : (91, 10001)
# Area_43 : (82, 10001)
# Area_OP4_PV : (103, 10001)
# Area_OP1_SII : (52, 10001)
# Area_OP2-3_VS : (47, 10001)
# Area_52 : (49, 10001)
# RetroInsular_Cortex : (88, 10001)
# Area_PFcm : (67, 10001)
# Posterior_Insular_Area_2 : (117, 10001)
# Area_TA2 : (69, 10001)
# Frontal_Opercular_Area_4 : (100, 10001)
# Middle_Insular_Area : (90, 10001)
# Piriform_Cortex : (129, 10001)
# Anterior_Ventral_Insular_Area : (84, 10001)
# Anterior_Agranular_Insula_Complex : (81, 10001)
# Frontal_Opercular_Area_1 : (39, 10001)
# Frontal_Opercular_Area_3 : (46, 10001)
# Frontal_Opercular_Area_2 : (49, 10001)
# Area_PFt : (102, 10001)
# Anterior_IntraParietal_Area : (126, 10001)
# Entorhinal_Cortex : (129, 10001)
# PreSubiculum : (113, 10001)
# Hippocampus : (273, 10001)
# ProStriate_Area : (68, 10001)
# Perirhinal_Ectorhinal_Cortex : (231, 10001)
# Area_STGa : (122, 10001)
# ParaBelt_Complex : (70, 10001)
# Auditory_5_Complex : (172, 10001)
# ParaHippocampal_Area_1 : (52, 10001)
# ParaHippocampal_Area_3 : (71, 10001)
# Area_STSd_anterior : (84, 10001)
# Area_STSd_posterior : (117, 10001)
# Area_STSv_posterior : (121, 10001)
# Area_TG_dorsal : (528, 10001)
# Area_TE1_anterior : (249, 10001)
# Area_TE1_posterior : (340, 10001)
# Area_TE2_anterior : (301, 10001)
# Area_TF : (230, 10001)
# Area_TE2_posterior : (182, 10001)
# Area_PHT : (185, 10001)
# Area_PH : (160, 10001)
# Area_TemporoParietoOccipital_Junction_1 : (156, 10001)
# Area_TemporoParietoOccipital_Junction_2 : (96, 10001)
# Area_TemporoParietoOccipital_Junction_3 : (65, 10001)
# Dorsal_Transitional_Visual_Area : (76, 10001)
# Area_PGp : (56, 10001)
# Area_IntraParietal_2 : (94, 10001)
# Area_IntraParietal_1 : (74, 10001)
# Area_IntraParietal_0 : (51, 10001)
# Area_PF_opercular : (75, 10001)
# Area_PF_Complex : (279, 10001)
# Area_PFm_Complex : (427, 10001)
# Area_PGi : (236, 10001)
# Area_PGs : (148, 10001)
# Area_V6A : (0, 0)
# VentroMedial_Visual_Area_1 : (45, 10001)
# VentroMedial_Visual_Area_3 : (44, 10001)
# ParaHippocampal_Area_2 : (40, 10001)
# Area_V4t : (36, 10001)
# Area_FST : (79, 10001)
# Area_V3CD : (2, 10001)
# Area_Lateral_Occipital_3 : (33, 10001)
# VentroMedial_Visual_Area_2 : (45, 10001)
# Area_31pd : (61, 10001)
# Area_31a : (47, 10001)
# Ventral_Visual_Complex : (159, 10001)
# Area_25 : (112, 10001)
# Area_s32 : (41, 10001)
# posterior_OFC_Complex : (160, 10001)
# Area_Posterior_Insular_1 : (90, 10001)
# Insular_Granular_Complex : (55, 10001)
# Area_Frontal_Opercular : (77, 10001)
# Area_posterior_10p : (119, 10001)
# Area_posterior_47r : (101, 10001)
# Area_TG_Ventral : (219, 10001)
# Medial_Belt_Complex : (59, 10001)
# Lateral_Belt_Complex : (48, 10001)
# Auditory_4_Complex : (184, 10001)
# Area_STSv_anterior : (85, 10001)
# Area_TE1_Middle : (171, 10001)
# Para-Insular_Area : (52, 10001)
# Area_anterior_32_prime : (84, 10001)
# Area_posterior_24 : (113, 10001)

# %% [markdown]
# #### save and load brain_region_nii_data_list

# %% [markdown]
# ##### save

# %%
import hdf5storage

matdic = {"brain_region_name_list":brain_region_name_list,
          "brain_region_nii_data_list":brain_region_nii_data_list}
file_dir = os.path.join(preprocessed_dir, subject_name)
hdf5storage.savemat(file_dir+"/brain_region_nii_data_list.mat", matdic)

# %% [markdown]
# ##### load

# %%
import hdf5storage

file_dir = os.path.join(preprocessed_dir, subject_name)
matdic = hdf5storage.loadmat(file_dir+"/brain_region_nii_data_list.mat", )

brain_region_nii_data_list = matdic["brain_region_nii_data_list"]
brain_region_name_list = matdic["brain_region_name_list"]

# %%
print("num of brain regions:", len(brain_region_nii_data_list))

for i in range(0, len(brain_region_name_list)):
    print(brain_region_name_list[i],':',brain_region_nii_data_list[i].shape)
# Out:
# num of brain regions: 180
# Primary_Visual_Cortex : (272, 10001)
# Medial_Superior_Temporal_Area : (41, 10001)
# Sixth_Visual_Area : (44, 10001)
# Second_Visual_Area : (201, 10001)
# Third_Visual_Area : (114, 10001)
# Fourth_Visual_Area : (47, 10001)
# Eighth_Visual_Area : (47, 10001)
# Primary_Motor_Cortex : (361, 10001)
# Primary_Sensory_Cortex : (182, 10001)
# Frontal_Eye_Fields : (87, 10001)
# Premotor_Eye_Fields : (57, 10001)
# Area_55b : (107, 10001)
# Area_V3A : (0, 0)
# RetroSplenial_Complex : (191, 10001)
# Parieto-Occipital_Sulcus_Area_2 : (130, 10001)
# Seventh_Visual_Area : (3, 10001)
# IntraParietal_Sulcus_Area_1 : (72, 10001)
# Fusiform_Face_Complex : (200, 10001)
# Area_V3B : (26, 10001)
# Area_Lateral_Occipital_1 : (12, 10001)
# Area_Lateral_Occipital_2 : (7, 10001)
# Posterior_InferoTemporal : (9, 10001)
# Middle_Temporal_Area : (40, 10001)
# Primary_Auditory_Cortex : (34, 10001)
# PeriSylvian_Language_Area : (120, 10001)
# Superior_Frontal_Language_Area : (127, 10001)
# PreCuneus_Visual_Area : (106, 10001)
# Superior_Temporal_Visual_Area : (108, 10001)
# Medial_Area_7P : (63, 10001)
# Area_7m : (86, 10001)
# Parieto-Occipital_Sulcus_Area_1 : (120, 10001)
# Area_23d : (48, 10001)
# Area_ventral_23_a+b : (44, 10001)
# Area_dorsal_23_a+b : (55, 10001)
# Area_31p_ventral : (57, 10001)
# Area_5m : (67, 10001)
# Area_5m_ventral : (111, 10001)
# Area_23c : (128, 10001)
# Area_5L : (17, 10001)
# Dorsal_Area_24d : (141, 10001)
# Ventral_Area_24d : (65, 10001)
# Lateral_Area_7A : (51, 10001)
# Supplementary_And_Cingulate_Eye : (141, 10001)
# Area_6m_anterior : (96, 10001)
# Medial_Area_7A : (113, 10001)
# Lateral_Area_7P : (70, 10001)
# Area_7PC : (130, 10001)
# Area_Lateral_IntraParietal_ventral : (101, 10001)
# Ventral_IntraParietal_Complex : (52, 10001)
# Medial_IntraParietal_Area : (124, 10001)
# Area_1 : (280, 10001)
# Area_2 : (216, 10001)
# Area_3a : (146, 10001)
# Dorsal_area_6 : (93, 10001)
# Area_6mp : (74, 10001)
# Ventral_Area_6 : (129, 10001)
# Area_Posterior_24_prime : (60, 10001)
# Area_33_prime : (91, 10001)
# Anterior_24_prime : (52, 10001)
# Area_p32_prime : (87, 10001)
# Area_a24 : (111, 10001)
# Area_dorsal_32 : (126, 10001)
# Area_8BM : (163, 10001)
# Area_p32 : (83, 10001)
# Area_10r : (57, 10001)
# Area_47m : (37, 10001)
# Area_8Av : (293, 10001)
# Area_8Ad : (183, 10001)
# Area_9_Middle : (302, 10001)
# Area_8B_Lateral : (215, 10001)
# Area_9_Posterior : (154, 10001)
# Area_10d : (188, 10001)
# Area_8C : (199, 10001)
# Area_44 : (116, 10001)
# Area_45 : (178, 10001)
# Area_47l_(47_lateral) : (139, 10001)
# Area_anterior_47r : (215, 10001)
# Rostral_Area_6 : (155, 10001)
# Area_IFJa : (67, 10001)
# Area_IFJp : (55, 10001)
# Area_IFSp : (89, 10001)
# Area__IFSa : (135, 10001)
# Area_posterior_9-46v : (188, 10001)
# Area_46 : (247, 10001)
# Area_anterior_9-46v : (153, 10001)
# Area_9-46d : (249, 10001)
# Area_9_anterior : (176, 10001)
# Area_10v : (140, 10001)
# Area_anterior_10p : (102, 10001)
# Polar_10p : (127, 10001)
# Area_11l : (199, 10001)
# Area_13l : (109, 10001)
# Orbital_Frontal_Complex : (249, 10001)
# Area_47s : (140, 10001)
# Area_Lateral_IntraParietal_dorsal : (63, 10001)
# Area_6_anterior : (222, 10001)
# Inferior_6-8_Transitional_Area : (115, 10001)
# Superior_6-8_Transitional_Area : (91, 10001)
# Area_43 : (82, 10001)
# Area_OP4_PV : (103, 10001)
# Area_OP1_SII : (52, 10001)
# Area_OP2-3_VS : (47, 10001)
# Area_52 : (49, 10001)
# RetroInsular_Cortex : (88, 10001)
# Area_PFcm : (67, 10001)
# Posterior_Insular_Area_2 : (117, 10001)
# Area_TA2 : (69, 10001)
# Frontal_Opercular_Area_4 : (100, 10001)
# Middle_Insular_Area : (90, 10001)
# Piriform_Cortex : (129, 10001)
# Anterior_Ventral_Insular_Area : (84, 10001)
# Anterior_Agranular_Insula_Complex : (81, 10001)
# Frontal_Opercular_Area_1 : (39, 10001)
# Frontal_Opercular_Area_3 : (46, 10001)
# Frontal_Opercular_Area_2 : (49, 10001)
# Area_PFt : (102, 10001)
# Anterior_IntraParietal_Area : (126, 10001)
# Entorhinal_Cortex : (129, 10001)
# PreSubiculum : (113, 10001)
# Hippocampus : (273, 10001)
# ProStriate_Area : (68, 10001)
# Perirhinal_Ectorhinal_Cortex : (231, 10001)
# Area_STGa : (122, 10001)
# ParaBelt_Complex : (70, 10001)
# Auditory_5_Complex : (172, 10001)
# ParaHippocampal_Area_1 : (52, 10001)
# ParaHippocampal_Area_3 : (71, 10001)
# Area_STSd_anterior : (84, 10001)
# Area_STSd_posterior : (117, 10001)
# Area_STSv_posterior : (121, 10001)
# Area_TG_dorsal : (528, 10001)
# Area_TE1_anterior : (249, 10001)
# Area_TE1_posterior : (340, 10001)
# Area_TE2_anterior : (301, 10001)
# Area_TF : (230, 10001)
# Area_TE2_posterior : (182, 10001)
# Area_PHT : (185, 10001)
# Area_PH : (160, 10001)
# Area_TemporoParietoOccipital_Junction_1 : (156, 10001)
# Area_TemporoParietoOccipital_Junction_2 : (96, 10001)
# Area_TemporoParietoOccipital_Junction_3 : (65, 10001)
# Dorsal_Transitional_Visual_Area : (76, 10001)
# Area_PGp : (56, 10001)
# Area_IntraParietal_2 : (94, 10001)
# Area_IntraParietal_1 : (74, 10001)
# Area_IntraParietal_0 : (51, 10001)
# Area_PF_opercular : (75, 10001)
# Area_PF_Complex : (279, 10001)
# Area_PFm_Complex : (427, 10001)
# Area_PGi : (236, 10001)
# Area_PGs : (148, 10001)
# Area_V6A : (0, 0)
# VentroMedial_Visual_Area_1 : (45, 10001)
# VentroMedial_Visual_Area_3 : (44, 10001)
# ParaHippocampal_Area_2 : (40, 10001)
# Area_V4t : (36, 10001)
# Area_FST : (79, 10001)
# Area_V3CD : (2, 10001)
# Area_Lateral_Occipital_3 : (33, 10001)
# VentroMedial_Visual_Area_2 : (45, 10001)
# Area_31pd : (61, 10001)
# Area_31a : (47, 10001)
# Ventral_Visual_Complex : (159, 10001)
# Area_25 : (112, 10001)
# Area_s32 : (41, 10001)
# posterior_OFC_Complex : (160, 10001)
# Area_Posterior_Insular_1 : (90, 10001)
# Insular_Granular_Complex : (55, 10001)
# Area_Frontal_Opercular : (77, 10001)
# Area_posterior_10p : (119, 10001)
# Area_posterior_47r : (101, 10001)
# Area_TG_Ventral : (219, 10001)
# Medial_Belt_Complex : (59, 10001)
# Lateral_Belt_Complex : (48, 10001)
# Auditory_4_Complex : (184, 10001)
# Area_STSv_anterior : (85, 10001)
# Area_TE1_Middle : (171, 10001)
# Para-Insular_Area : (52, 10001)
# Area_anterior_32_prime : (84, 10001)
# Area_posterior_24 : (113, 10001)

# %% [markdown]
# ### check the final results

# %% [markdown]
# #### check average of each region

# %%
vol_src = mne.read_source_spaces(preprocessed_subject_path_str + "/src/vol-src.fif")
source_estimate_vol_str = preprocessed_subject_path_str + "/src/vol_stcfile/vol-TS_src_-vl.stc"
stc_vol= mne.read_source_estimate(source_estimate_vol_str)

print("check source vol...")
print("vol_src:", vol_src, '\n num:', 39 * 46 * 40)
print("stc_vol:", stc_vol)
# Out:
#     Reading a source space...
#     [done]
#     1 source spaces read
# check source vol...
# vol_src: <SourceSpaces: [<volume, shape=(39, 46, 40), n_used=30659>] MRI (surface RAS) coords, ~82.6 MB>
#  num: 71760
# stc_vol: <VolSourceEstimate | 30659 vertices, tmin : 0.0 (ms), tmax : 10000.0 (ms), tstep : 1.0 (ms), data shape : (30659, 10001), ~1.14 GB>

# %%
from scipy.io import loadmat

matdic = loadmat(preprocessed_subject_path_str + "/src/ROI_tc/" + "ts_HCPmmp_lh_sub-test.mat")

ts_lh = np.squeeze(matdic["ts_lh"])
print("ts_lh shape =", ts_lh.shape)
# Out:
# ts_lh shape = (180, 10001)

# %% [markdown]
# #### check each region with mask

# %% [markdown]
# ##### load

# %%
import hdf5storage

file_dir = os.path.join(preprocessed_dir, subject_name)
matdic = hdf5storage.loadmat(file_dir+"/brain_region_nii_data_list.mat", )

brain_region_nii_data_list = matdic["brain_region_nii_data_list"]
brain_region_name_list = matdic["brain_region_name_list"]

# %%
print("num of brain regions:", len(brain_region_nii_data_list))

for i in range(0, len(brain_region_name_list)):
    print(brain_region_name_list[i],':',brain_region_nii_data_list[i].shape)
# Out:
# num of brain regions: 180
# Primary_Visual_Cortex : (272, 10001)
# Medial_Superior_Temporal_Area : (41, 10001)
# Sixth_Visual_Area : (44, 10001)
# Second_Visual_Area : (201, 10001)
# Third_Visual_Area : (114, 10001)
# Fourth_Visual_Area : (47, 10001)
# Eighth_Visual_Area : (47, 10001)
# Primary_Motor_Cortex : (361, 10001)
# Primary_Sensory_Cortex : (182, 10001)
# Frontal_Eye_Fields : (87, 10001)
# Premotor_Eye_Fields : (57, 10001)
# Area_55b : (107, 10001)
# Area_V3A : (0, 0)
# RetroSplenial_Complex : (191, 10001)
# Parieto-Occipital_Sulcus_Area_2 : (130, 10001)
# Seventh_Visual_Area : (3, 10001)
# IntraParietal_Sulcus_Area_1 : (72, 10001)
# Fusiform_Face_Complex : (200, 10001)
# Area_V3B : (26, 10001)
# Area_Lateral_Occipital_1 : (12, 10001)
# Area_Lateral_Occipital_2 : (7, 10001)
# Posterior_InferoTemporal : (9, 10001)
# Middle_Temporal_Area : (40, 10001)
# Primary_Auditory_Cortex : (34, 10001)
# PeriSylvian_Language_Area : (120, 10001)
# Superior_Frontal_Language_Area : (127, 10001)
# PreCuneus_Visual_Area : (106, 10001)
# Superior_Temporal_Visual_Area : (108, 10001)
# Medial_Area_7P : (63, 10001)
# Area_7m : (86, 10001)
# Parieto-Occipital_Sulcus_Area_1 : (120, 10001)
# Area_23d : (48, 10001)
# Area_ventral_23_a+b : (44, 10001)
# Area_dorsal_23_a+b : (55, 10001)
# Area_31p_ventral : (57, 10001)
# Area_5m : (67, 10001)
# Area_5m_ventral : (111, 10001)
# Area_23c : (128, 10001)
# Area_5L : (17, 10001)
# Dorsal_Area_24d : (141, 10001)
# Ventral_Area_24d : (65, 10001)
# Lateral_Area_7A : (51, 10001)
# Supplementary_And_Cingulate_Eye : (141, 10001)
# Area_6m_anterior : (96, 10001)
# Medial_Area_7A : (113, 10001)
# Lateral_Area_7P : (70, 10001)
# Area_7PC : (130, 10001)
# Area_Lateral_IntraParietal_ventral : (101, 10001)
# Ventral_IntraParietal_Complex : (52, 10001)
# Medial_IntraParietal_Area : (124, 10001)
# Area_1 : (280, 10001)
# Area_2 : (216, 10001)
# Area_3a : (146, 10001)
# Dorsal_area_6 : (93, 10001)
# Area_6mp : (74, 10001)
# Ventral_Area_6 : (129, 10001)
# Area_Posterior_24_prime : (60, 10001)
# Area_33_prime : (91, 10001)
# Anterior_24_prime : (52, 10001)
# Area_p32_prime : (87, 10001)
# Area_a24 : (111, 10001)
# Area_dorsal_32 : (126, 10001)
# Area_8BM : (163, 10001)
# Area_p32 : (83, 10001)
# Area_10r : (57, 10001)
# Area_47m : (37, 10001)
# Area_8Av : (293, 10001)
# Area_8Ad : (183, 10001)
# Area_9_Middle : (302, 10001)
# Area_8B_Lateral : (215, 10001)
# Area_9_Posterior : (154, 10001)
# Area_10d : (188, 10001)
# Area_8C : (199, 10001)
# Area_44 : (116, 10001)
# Area_45 : (178, 10001)
# Area_47l_(47_lateral) : (139, 10001)
# Area_anterior_47r : (215, 10001)
# Rostral_Area_6 : (155, 10001)
# Area_IFJa : (67, 10001)
# Area_IFJp : (55, 10001)
# Area_IFSp : (89, 10001)
# Area__IFSa : (135, 10001)
# Area_posterior_9-46v : (188, 10001)
# Area_46 : (247, 10001)
# Area_anterior_9-46v : (153, 10001)
# Area_9-46d : (249, 10001)
# Area_9_anterior : (176, 10001)
# Area_10v : (140, 10001)
# Area_anterior_10p : (102, 10001)
# Polar_10p : (127, 10001)
# Area_11l : (199, 10001)
# Area_13l : (109, 10001)
# Orbital_Frontal_Complex : (249, 10001)
# Area_47s : (140, 10001)
# Area_Lateral_IntraParietal_dorsal : (63, 10001)
# Area_6_anterior : (222, 10001)
# Inferior_6-8_Transitional_Area : (115, 10001)
# Superior_6-8_Transitional_Area : (91, 10001)
# Area_43 : (82, 10001)
# Area_OP4_PV : (103, 10001)
# Area_OP1_SII : (52, 10001)
# Area_OP2-3_VS : (47, 10001)
# Area_52 : (49, 10001)
# RetroInsular_Cortex : (88, 10001)
# Area_PFcm : (67, 10001)
# Posterior_Insular_Area_2 : (117, 10001)
# Area_TA2 : (69, 10001)
# Frontal_Opercular_Area_4 : (100, 10001)
# Middle_Insular_Area : (90, 10001)
# Piriform_Cortex : (129, 10001)
# Anterior_Ventral_Insular_Area : (84, 10001)
# Anterior_Agranular_Insula_Complex : (81, 10001)
# Frontal_Opercular_Area_1 : (39, 10001)
# Frontal_Opercular_Area_3 : (46, 10001)
# Frontal_Opercular_Area_2 : (49, 10001)
# Area_PFt : (102, 10001)
# Anterior_IntraParietal_Area : (126, 10001)
# Entorhinal_Cortex : (129, 10001)
# PreSubiculum : (113, 10001)
# Hippocampus : (273, 10001)
# ProStriate_Area : (68, 10001)
# Perirhinal_Ectorhinal_Cortex : (231, 10001)
# Area_STGa : (122, 10001)
# ParaBelt_Complex : (70, 10001)
# Auditory_5_Complex : (172, 10001)
# ParaHippocampal_Area_1 : (52, 10001)
# ParaHippocampal_Area_3 : (71, 10001)
# Area_STSd_anterior : (84, 10001)
# Area_STSd_posterior : (117, 10001)
# Area_STSv_posterior : (121, 10001)
# Area_TG_dorsal : (528, 10001)
# Area_TE1_anterior : (249, 10001)
# Area_TE1_posterior : (340, 10001)
# Area_TE2_anterior : (301, 10001)
# Area_TF : (230, 10001)
# Area_TE2_posterior : (182, 10001)
# Area_PHT : (185, 10001)
# Area_PH : (160, 10001)
# Area_TemporoParietoOccipital_Junction_1 : (156, 10001)
# Area_TemporoParietoOccipital_Junction_2 : (96, 10001)
# Area_TemporoParietoOccipital_Junction_3 : (65, 10001)
# Dorsal_Transitional_Visual_Area : (76, 10001)
# Area_PGp : (56, 10001)
# Area_IntraParietal_2 : (94, 10001)
# Area_IntraParietal_1 : (74, 10001)
# Area_IntraParietal_0 : (51, 10001)
# Area_PF_opercular : (75, 10001)
# Area_PF_Complex : (279, 10001)
# Area_PFm_Complex : (427, 10001)
# Area_PGi : (236, 10001)
# Area_PGs : (148, 10001)
# Area_V6A : (0, 0)
# VentroMedial_Visual_Area_1 : (45, 10001)
# VentroMedial_Visual_Area_3 : (44, 10001)
# ParaHippocampal_Area_2 : (40, 10001)
# Area_V4t : (36, 10001)
# Area_FST : (79, 10001)
# Area_V3CD : (2, 10001)
# Area_Lateral_Occipital_3 : (33, 10001)
# VentroMedial_Visual_Area_2 : (45, 10001)
# Area_31pd : (61, 10001)
# Area_31a : (47, 10001)
# Ventral_Visual_Complex : (159, 10001)
# Area_25 : (112, 10001)
# Area_s32 : (41, 10001)
# posterior_OFC_Complex : (160, 10001)
# Area_Posterior_Insular_1 : (90, 10001)
# Insular_Granular_Complex : (55, 10001)
# Area_Frontal_Opercular : (77, 10001)
# Area_posterior_10p : (119, 10001)
# Area_posterior_47r : (101, 10001)
# Area_TG_Ventral : (219, 10001)
# Medial_Belt_Complex : (59, 10001)
# Lateral_Belt_Complex : (48, 10001)
# Auditory_4_Complex : (184, 10001)
# Area_STSv_anterior : (85, 10001)
# Area_TE1_Middle : (171, 10001)
# Para-Insular_Area : (52, 10001)
# Area_anterior_32_prime : (84, 10001)
# Area_posterior_24 : (113, 10001)
